# %%
import pandas as pd

# %%
#Task 0 open data/titanic.csv

titanic_df= pd.read_csv("./data/titanic.csv")
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df.iloc[0][0]
# Out:
# C:\Users\rukhm\AppData\Local\Temp\ipykernel_11072\1783678975.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   titanic_df.iloc[0][0]
# 1

# %%
#Task 1 how many passangers are in the data?
titanic_df['PassengerId'].count()
# Out:
# 891

# %%
#Task 2 How many distinct Surnames can you see in the data?

titanic_df.Name.unique()
# Out:
# array(['Braund, Mr. Owen Harris',
#        'Cumings, Mrs. John Bradley (Florence Briggs Thayer)',
#        'Heikkinen, Miss. Laina',
#        'Futrelle, Mrs. Jacques Heath (Lily May Peel)',
#        'Allen, Mr. William Henry', 'Moran, Mr. James',
#        'McCarthy, Mr. Timothy J', 'Palsson, Master. Gosta Leonard',
#        'Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)',
#        'Nasser, Mrs. Nicholas (Adele Achem)',
#        'Sandstrom, Miss. Marguerite Rut', 'Bonnell, Miss. Elizabeth',
#        'Saundercock, Mr. William Henry', 'Andersson, Mr. Anders Johan',
#        'Vestrom, Miss. Hulda Amanda Adolfina',
#        'Hewlett, Mrs. (Mary D Kingcome) ', 'Rice, Master. Eugene',
#        'Williams, Mr. Charles Eugene',
#        'Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)',
#        'Masselmani, Mrs. Fatima', 'Fynney, Mr. Joseph J',
#        'Beesley, Mr. Lawrence', 'McGowan, Miss. Anna "Annie"',
# ...

# %%
#Task 3 sum Fare per A) location of Embarked B) Locatio of Embarked and Sex 
#result should be dataframe

result_df = titanic_df.groupby('Embarked')['Fare'].agg(['sum'])
result_df

result_df_new = titanic_df.groupby(['Embarked', 'Sex'])['Fare'].agg(['sum'])
result_df_new
# Out:
#                        sum
# Embarked Sex
# C        female  5487.3958
#          male    4584.9004
# Q        female   454.8585
#          male     567.3958
# S        female  7864.4085
#          male    9574.9903

# %%
#Task 4 How wold you drop all rows that contain none? 
rows_none = titanic_df.isna()


#rows_none #gives a boolean table where if its true that position has a NaN value
 
titanic_df[rows_none['Cabin'] ==0] #This condition selects only the rows where the Cabin column does not 
#have NaN values (because False means no NaN).


# How about dropping tows that have none in Cabin?
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 5 Use columns SibSp and Parch to form binary attribute has_family (use max or addition of two columns)
import numpy as np
titanic_df['has_family']= titanic_df.SibSp + titanic_df.Parch
titanic_df['has_family'] = titanic_df['has_family'].apply(lambda x: x-(x-1)  if x>0 else (x-x))
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Task 6 drop column has family 
titanic_df = titanic_df.drop(['has_family'], axis =1)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 7 Use conditions approach to form has_family attriubte
condition = (titanic_df.SibSp > 0) | (titanic_df.Parch > 0)

titanic_df.loc[titanic_df[condition], 'has_family'] =1
titanic_df

# %%
condition = (titanic_df.SibSp > 0) | (titanic_df.Parch > 0)
titanic_df['has family'] = 0
# titanic_df['has family'][condition]=1
titanic_df.loc[condition, 'has family'] = 1 #using this instead of previous because of depracation warning
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 8 What is the overall age average? What is the age average for women? And for men?

titanic_df.groupby('Sex')['Age'].agg(['mean'])
# Out:
#              mean
# Sex
# female  27.915709
# male    30.726645

# %%
#Task 9 how many passerngers traveled on their own (alone)?
(titanic_df['has family'] == 0).sum() #.sum() then adds up all the True values, treating True as 1 and False as 0.
# Out:
# 537

# %%
(titanic_df['has family'] ==1).sum() #number of people with family
# Out:
# 354

# %%
#Task 10 is there any effect of class passengers traveled in and survival rate?

titanic_df[['Pclass', 'Survived']]

condition_two = (titanic_df.Survived ==0)

# Filter for rows where passengers did not survive
non_survivors = titanic_df.loc[condition_two, ['Pclass', 'Survived']]

# Display the filtered table
non_survivors

third_class_unalive = (non_survivors['Pclass'] ==3).sum()
second_class_unalive = (non_survivors['Pclass']==2).sum()
first_class_unalive = (non_survivors['Pclass']==1).sum()

print(f'total number of non-survivors is {len(non_survivors)} out of which {(third_class_unalive/len(non_survivors))*100} % is from third class')
# Out:
# total number of non-survivors is 549 out of which 67.75956284153006 % is from third class

# %%
#chatgpt improved way of printing info:
total_non_survivors = len(non_survivors)
# Display percentage of non-survivors in each class
print(f"Total number of non-survivors: {total_non_survivors}")
print(f"Percentage of non-survivors from third class: {(third_class_unalive / total_non_survivors) * 100:.2f}%")
print(f"Percentage of non-survivors from second class: {(second_class_unalive / total_non_survivors) * 100:.2f}%")
print(f"Percentage of non-survivors from first class: {(first_class_unalive / total_non_survivors) * 100:.2f}%")
# Out:
# Total number of non-survivors: 549
# Percentage of non-survivors from third class: 67.76%
# Percentage of non-survivors from second class: 17.67%
# Percentage of non-survivors from first class: 14.57%

# %%
#chatgpt for visualization

import matplotlib.pyplot as plt

# Prepare data for visualization
non_survivor_counts = [third_class_unalive, second_class_unalive, first_class_unalive]
classes = ['Third Class', 'Second Class', 'First Class']

# Plotting
plt.bar(classes, non_survivor_counts)
plt.title("Non-Survivor Counts by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Non-Survivors")
plt.show()

# %%
#Task 11 Do missing cabin values have something incommon with Pclass?

missing_cabin_values = titanic_df["Cabin"].isna()  #finding out number of values in "Cabin" that are NaN
missing_cabin_values.sum() #total number of NaN values

#grouping based on class and then getting number of NaN cabins by taking sum of NaNs under each group of 'Pclass'
missing_cabin_by_class = titanic_df.groupby('Pclass')['Cabin'].apply(lambda x: x.isna().sum()) 

print("Number of Missing Cabin Values per Class:")
print(missing_cabin_by_class)
# Out:
# Number of Missing Cabin Values per Class:
# Pclass
# 1     40
# 2    168
# 3    479
# Name: Cabin, dtype: int64

# %%
#Task 12 Create new column family name, count members of the family in data
titanic_df["family_name"] = titanic_df["Name"].apply(lambda x: x.split(',')[0]) #here x will titanic_df[Name]

grouped_by_surname = pd.DataFrame(titanic_df.groupby("family_name")['family_name'].apply(lambda x: x.count()))
grouped_by_surname.rename(columns={"family_name":"no_of_family_members"}, inplace=True)
grouped_by_surname
# Out:
#                no_of_family_members
# family_name
# Abbing                            1
# Abbott                            2
# Abelson                           2
# Adahl                             1
# Adams                             1
# ...                             ...
# de Mulder                         1
# de Pelsmaeker                     1
# del Carlo                         1
# van Billiard                      1
# van Melkebeke                     1
#
# [667 rows x 1 columns]

# %%
#titanic_df = titanic_df.drop("Number of family members", axis=1)
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
titanic_df[titanic_df["PassengerId"]==634]
# Out:
#      PassengerId  Survived  Pclass                           Name   Sex  Age  \
# 633          634         0       1  Parr, Mr. William Henry Marsh  male  NaN
#
#      SibSp  Parch  Ticket  Fare Cabin Embarked  has family family_name
# 633      0      0  112052   0.0   NaN        S           0        Parr

# %%
#Task 13 group Fare by 3 thresholds so you have category cheap fare, regular fare, expensive fare
minimum_fare = titanic_df.Fare.min()
mid_fare = titanic_df.Fare.median()
max_fare = titanic_df.Fare.max()


# Define bins with an additional threshold for clear separation
titanic_df['fare_category'] = pd.cut(
    titanic_df['Fare'],
    bins=[minimum_fare, mid_fare, (mid_fare + max_fare) / 10, max_fare],
    labels=['cheap fare', 'regular fare', 'expensive fare'],
    include_lowest=True
)

# Display the updated DataFrame
titanic_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#Task 14 form an empty dataset, append counts in fare category to it
empty_dataset = pd.DataFrame([])
empty_dataset['Fare_category'] = titanic_df.fare_category.unique()
empty_dataset['Passenger_Count'] = titanic_df.groupby('fare_category', as_index=False)['fare_category'].count()

empty_dataset
# Out:
# C:\Users\rukhm\AppData\Local\Temp\ipykernel_40644\3721632266.py:4: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   empty_dataset['Passenger_Count'] = titanic_df.groupby('fare_category', as_index=False)['fare_category'].count()
#     Fare_category  Passenger_Count
# 0      cheap fare              447
# 1  expensive fare              298
# 2    regular fare              146

# %%
#Task 15 rename column PassengerId in appended dataframe to Passenger Count
#already done before
